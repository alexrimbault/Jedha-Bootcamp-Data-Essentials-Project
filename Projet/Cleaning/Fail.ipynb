# %%
#IMPORTING LIBRARIES

import pandas as pd

# %%
#IMPORTING THE TWO DATAFRAMES

df_unicorn = pd.read_csv('Unicorn_Clean.csv')
df_crunchbase = pd.read_csv('comp.csv')

# %%
#CHECKING THE FIRST DATAFRAME

df_unicorn
# Out:
#      Unnamed: 0          Company  Valuation ($B) Date Joined        Country  \
# 0             0        Bytedance           140.0  2017-04-07          China
# 1             1           SpaceX           100.3  2012-12-01  United States
# 2             2           Stripe            95.0  2014-01-23  United States
# 3             3           Klarna            45.6  2011-12-12         Sweden
# 4             4            Canva            40.0  2018-01-08      Australia
# ..          ...              ...             ...         ...            ...
# 931         931        YipitData             1.0  2021-12-06  United States
# 932         932         Anyscale             1.0  2021-12-07  United States
# 933         933  Iodine Software             1.0  2021-12-01  United States
# 934         934       ReliaQuest             1.0  2021-12-01  United States
# 935         935       Pet Circle             1.0  2021-12-07      Australia
#
#               City                         Industry  \
# ...

# %%
#CHECKING THE COLUMNS IN FIRST DATASET

df_unicorn.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'Valuation ($B)', 'Date Joined', 'Country',
#        'City', 'Industry', 'Investor 1', 'Investor 2', 'Investor 3',
#        'Investor 4'],
#       dtype='object')

# %%
#DROPPING THE COLUMNS WHICH ARE IRRELEVANT IN FIRST DATASET

df_unicorn.drop(columns = ['Unnamed: 0','Investor 1', 'Investor 2', 'Investor 3','Investor 4'], axis=1, inplace=True)

# %%
#CHECKING THE NEW FIRST DATASET WHICH HAVE BEEN FORMATED

df_unicorn
# Out:
#              Company  Valuation ($B) Date Joined        Country  \
# 0          Bytedance           140.0  2017-04-07          China
# 1             SpaceX           100.3  2012-12-01  United States
# 2             Stripe            95.0  2014-01-23  United States
# 3             Klarna            45.6  2011-12-12         Sweden
# 4              Canva            40.0  2018-01-08      Australia
# ..               ...             ...         ...            ...
# 931        YipitData             1.0  2021-12-06  United States
# 932         Anyscale             1.0  2021-12-07  United States
# 933  Iodine Software             1.0  2021-12-01  United States
# 934       ReliaQuest             1.0  2021-12-01  United States
# 935       Pet Circle             1.0  2021-12-07      Australia
#
#               City                         Industry
# 0          Beijing          Artificial intelligence
# 1        Hawthorne                            Other
# ...

# %%
#CHECKING THE TYPE OF EACH COLUMN

df_unicorn.dtypes
# Out:
# Company            object
# Valuation ($B)    float64
# Date Joined        object
# Country            object
# City               object
# Industry           object
# dtype: object

# %%
#CONVERTING THE 'DATE JOINED' COLUMN FROM AN OBJECT TO A DATETIME

df_unicorn['Date Joined'] = pd.to_datetime(df_unicorn['Date Joined'])
df_unicorn.dtypes
# Out:
# Company                   object
# Valuation ($B)           float64
# Date Joined       datetime64[ns]
# Country                   object
# City                      object
# Industry                  object
# dtype: object

# %%
# KEEPING ONLY THE YEAR IN THE COLUMN 'Date Joined',
# DROPPING THE 'Date Joined' COLUMN

df_unicorn['Year Joined'] = df_unicorn['Date Joined'].dt.to_period('Y')
df_unicorn.drop(columns = ['Date Joined'],axis=1, inplace=True)
df_unicorn
# Out:
#              Company  Valuation ($B)        Country           City  \
# 0          Bytedance           140.0          China        Beijing
# 1             SpaceX           100.3  United States      Hawthorne
# 2             Stripe            95.0  United States  San Francisco
# 3             Klarna            45.6         Sweden      Stockholm
# 4              Canva            40.0      Australia    Surry Hills
# ..               ...             ...            ...            ...
# 931        YipitData             1.0  United States       New York
# 932         Anyscale             1.0  United States       Berkeley
# 933  Iodine Software             1.0  United States         Austin
# 934       ReliaQuest             1.0  United States          Tampa
# 935       Pet Circle             1.0      Australia     Alexandria
#
#                             Industry Year Joined
# 0            Artificial intelligence        2017
# 1                              Other        2012
# ...

# %%
#SHIFTING THE COLUMN YEAR BACK TO ITS INITIAL POSITION

shift = df_unicorn.pop('Year Joined')
df_unicorn.insert(2, 'Year Joined', shift)
df_unicorn
# Out:
#              Company  Valuation ($B) Year Joined        Country  \
# 0          Bytedance           140.0        2017          China
# 1             SpaceX           100.3        2012  United States
# 2             Stripe            95.0        2014  United States
# 3             Klarna            45.6        2011         Sweden
# 4              Canva            40.0        2018      Australia
# ..               ...             ...         ...            ...
# 931        YipitData             1.0        2021  United States
# 932         Anyscale             1.0        2021  United States
# 933  Iodine Software             1.0        2021  United States
# 934       ReliaQuest             1.0        2021  United States
# 935       Pet Circle             1.0        2021      Australia
#
#               City                         Industry
# 0          Beijing          Artificial intelligence
# 1        Hawthorne                            Other
# ...

# %%
#CHECKING THE SECOND DATASET

df_crunchbase
# Out:
#                                          permalink  \
# 0                              /organization/-fame
# 1                           /organization/-qounter
# 2              /organization/-the-one-of-them-inc-
# 3                            /organization/0-6-com
# 4                   /organization/004-technologies
# ...                                            ...
# 13821           /organization/critical-diagnostics
# 13822       /organization/critical-links-solutions
# 13823                 /organization/critical-media
# 13824               /organization/critical-mention
# 13825  /organization/critical-outcome-technologies
#
#                                 name                       homepage_url  \
# 0                              #fame                 http://livfame.com
# 1                           :Qounter             http://www.qounter.com
# 2             (THE) ONE of THEM,Inc.                http://oneofthem.jp
# ...

# %%
#CHECKING THE COLUMNS IN SECOND DATASET

df_crunchbase.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list',
#        'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'first_funding_at',
#        'last_funding_at'],
#       dtype='object')

# %%
#DROPPING THE COLUMNS WHICH ARE IRRELEVANT IN SECOND DATASET

df_crunchbase.drop(columns = ['permalink','homepage_url', 'country_code', 'state_code','region','city','category_list'], axis=1,inplace=True)

# %%
#CHECKING THE NEW SECOND DATASET WHICH HAVE BEEN FORMATED

df_crunchbase
# Out:
#                                 name funding_total_usd     status  \
# 0                              #fame          10000000  operating
# 1                           :Qounter            700000  operating
# 2             (THE) ONE of THEM,Inc.           3406878  operating
# 3                            0-6.com           2000000  operating
# 4                   004 Technologies                 -  operating
# ...                              ...               ...        ...
# 13821           Critical Diagnostics           2566676  operating
# 13822                 Critical Links          11400000  operating
# 13823                 Critical Media           6200000  operating
# 13824               Critical Mention           2000000  operating
# 13825  Critical Outcome Technologies           1690312        NaN
#
#        funding_rounds  founded_at first_funding_at last_funding_at
# 0                 1.0         NaN       2015-01-05      2015-01-05
# ...

# %%
#CHECKING THE TYPE OF EACH COLUMN

df_crunchbase.dtypes
# Out:
# name                  object
# funding_total_usd     object
# status                object
# funding_rounds       float64
# founded_at            object
# first_funding_at      object
# last_funding_at       object
# dtype: object

# %%
#CONVERTING THE 3 DATES COLUMNS FROM AN OBJECT TO A DATETIME

df_crunchbase['founded_at'] = pd.to_datetime(df_crunchbase['founded_at'], errors = 'coerce')
df_crunchbase['first_funding_at'] = pd.to_datetime(df_crunchbase['first_funding_at'], errors = 'coerce')
df_crunchbase['last_funding_at'] = pd.to_datetime(df_crunchbase['last_funding_at'])
df_crunchbase.dtypes
# Out:
# name                         object
# funding_total_usd            object
# status                       object
# funding_rounds              float64
# founded_at           datetime64[ns]
# first_funding_at     datetime64[ns]
# last_funding_at      datetime64[ns]
# dtype: object

# %%
# KEEPING ONLY THE YEAR IN THE DATES COLUMNS,
# DROPPING THE 3 INITIALS COLUMNS 

df_crunchbase['founded_at'] = df_crunchbase['founded_at'].dt.to_period('Y')
df_crunchbase['first_funding_at'] = df_crunchbase['first_funding_at'].dt.to_period('Y')
df_crunchbase['last_funding_at'] = df_crunchbase['last_funding_at'].dt.to_period('Y')
df_crunchbase
# Out:
#                                 name funding_total_usd     status  \
# 0                              #fame          10000000  operating
# 1                           :Qounter            700000  operating
# 2             (THE) ONE of THEM,Inc.           3406878  operating
# 3                            0-6.com           2000000  operating
# 4                   004 Technologies                 -  operating
# ...                              ...               ...        ...
# 13821           Critical Diagnostics           2566676  operating
# 13822                 Critical Links          11400000  operating
# 13823                 Critical Media           6200000  operating
# 13824               Critical Mention           2000000  operating
# 13825  Critical Outcome Technologies           1690312        NaN
#
#        funding_rounds founded_at first_funding_at last_funding_at
# 0                 1.0        NaT             2015            2015
# ...

# %%
#RENAMING THE COMPANY NAME COLUMN OF THE SECOND DATASET

df_crunchbase.rename(columns={"name":"Company"}, inplace=True)

# %%
#FUNCTION ALLOWING TO CHECK THE NUMBER OF MATCHING VALUES BETWEEN THE TWO COMPANIES COLUMNS, 
#OF THE TWO DATASET

common = []

def lower(x):
    return x.lower()
for company in df_unicorn['Company'].apply(lower):
    if df_crunchbase[df_crunchbase['Company'].apply(lower).str.find(company) != -1].shape[0] != 0:
        common.append(company)

# %%
#CHECKING THE NUMBER OF MATCHING VALUES

len(common)
# Out:
# 148

# %%
#MERGING THE TWO DATASETS

df_final = df_unicorn.merge(df_crunchbase, on="Company", how = 'inner')

# %%
#CHECKING THE NEW AND FINAL DATASET COMING FROM THE MERGE

df_final
# Out:
#               Company  Valuation ($B) Year Joined        Country  \
# 0               Canva            40.0        2018      Australia
# 1               Chime            25.0        2019  United States
# 2               Chime            25.0        2019  United States
# 3           Benchling             6.1        2021  United States
# 4                Bolt             6.0        2021  United States
# ..                ...             ...         ...            ...
# 61             Bringg             1.0        2021         Israel
# 62            Aircall             1.0        2021  United States
# 63           Assembly             1.0        2021  United States
# 64             Augury             1.0        2021  United States
# 65  Contrast Security             1.0        2021  United States
#
#              City                           Industry funding_total_usd  \
# 0     Surry Hills       Internet software & services          27955000
# ...

# %%
df_final.drop(2)
# Out:
#               Company  Valuation ($B) Year Joined        Country  \
# 0               Canva            40.0        2018      Australia
# 1               Chime            25.0        2019  United States
# 3           Benchling             6.1        2021  United States
# 4                Bolt             6.0        2021  United States
# 5                Bolt             6.0        2021  United States
# ..                ...             ...         ...            ...
# 61             Bringg             1.0        2021         Israel
# 62            Aircall             1.0        2021  United States
# 63           Assembly             1.0        2021  United States
# 64             Augury             1.0        2021  United States
# 65  Contrast Security             1.0        2021  United States
#
#              City                           Industry funding_total_usd  \
# 0     Surry Hills       Internet software & services          27955000
# ...
